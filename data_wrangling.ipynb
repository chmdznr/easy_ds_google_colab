# %% [markdown]
# # Data Input

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1f9e21b-008b-4644-a1ed-fb68f7f8f881" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1f9e21b-008b-4644-a1ed-fb68f7f8f881">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ex6data1.mat to ex6data1.mat

# %%
# !pwd
# Out:
# /content

# %%
# !ls -al
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Oct 14 03:37 .
# drwxr-xr-x 1 root root 4096 Oct 14 03:26 ..
# drwxr-xr-x 4 root root 4096 Oct  8 13:44 .config
# drwx------ 5 root root 4096 Oct 14 03:37 drive
# -rw-r--r-- 1 root root  981 Oct 14 03:35 ex6data1.mat
# drwxr-xr-x 1 root root 4096 Oct  8 13:45 sample_data

# %%
# !cp sample_data/README.md drive/MyDrive/

# %%
# !ls drive/MyDrive/*.md
# Out:
# drive/MyDrive/README.md

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# data_olah   DataFrame           housing_median_age<...>n[17000 rows x 7 columns]
# files       module       <module 'google.colab.fil<...>s/google/colab/files.py'>
# pd          module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# rawdata     DataFrame           longitude  latitud<...>n[17000 rows x 9 columns]
# uploaded    dict         n=1

# %% [markdown]
# ## Read Data

# %%
# %load_ext google.colab.data_table

# %%
import pandas as pd

rawdata = pd.read_csv('sample_data/california_housing_train.csv')

# %%
rawdata
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
data_olah = rawdata.drop(['longitude', 'latitude'], axis=1).copy()

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [20, 10]

data_olah.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac70c2fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac6aceb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac6a861d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac6a3e850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac69f3ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac69b5550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac696ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac692b250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7ac692b290>]],
#       dtype=object)

# %%
data_olah
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
data_olah.describe()
# Out:
#        housing_median_age   total_rooms  ...  median_income  median_house_value
# count        17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean            28.589353   2643.664412  ...       3.883578       207300.912353
# std             12.586937   2179.947071  ...       1.908157       115983.764387
# min              1.000000      2.000000  ...       0.499900        14999.000000
# 25%             18.000000   1462.000000  ...       2.566375       119400.000000
# 50%             29.000000   2127.000000  ...       3.544600       180400.000000
# 75%             37.000000   3151.250000  ...       4.767000       265000.000000
# max             52.000000  37937.000000  ...      15.000100       500001.000000
#
# [8 rows x 7 columns]

# %%
data_olah['city'] = numpy.array([])
